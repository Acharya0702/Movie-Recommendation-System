# %%
import pandas as pd

# %%
df=pd.read_csv('reviews.txt', sep='\t')

# %%
df.to_csv('reviews.csv', index=False)

# %%
df=pd.read_csv('reviews.csv')

# %%
pd.set_option('display.max_columns', None)
df
# Out:
#       1            The Da Vinci Code book is just awesome.
# 0     1  this was the first clive cussler i've ever rea...
# 1     1                   i liked the Da Vinci Code a lot.
# 2     1                   i liked the Da Vinci Code a lot.
# 3     1  I liked the Da Vinci Code but it ultimatly did...
# 4     1  that's not even an exaggeration ) and at midni...
# 5     1  I loved the Da Vinci Code, but now I want some...
# 6     1  i thought da vinci code was great, same with k...
# 7     1      The Da Vinci Code is actually a good movie...
# 8     1  I thought the Da Vinci Code was a pretty good ...
# 9     1  The Da Vinci Code is one of the most beautiful...
# 10    1  The Da Vinci Code is an * amazing * book, do n...
# 11    1  then I turn on the light and the radio and enj...
# 12    1                 The Da Vinci Code was REALLY good.
# 13    1                           i love da vinci code....
# 14    1                            i loved da vinci code..
# 15    1  TO NIGHT:: THE DA VINCI CODE AND A BEAUTIFUL M...
# 16    1           THE DA VINCI CODE is AN AWESOME BOOK....
# 17    1             Thing is, I enjoyed The Da Vinci Code.
# 18    1             very da vinci code slash amazing race.
# 19    1                   Hey I loved The Da Vinci Code!..
# 20    1                     also loved the da vinci code..
# 21    1  I really enjoyed the Da Vinci Code but thought...
# 22    1  I do like Angels and Demons more then The Da V...
# 23    1         The Da Vinci Code was a really good movie.
# 24    1  yeah, da vinci code is an awesome movie i like...
# 25    1                   I really like The Da Vinci Code.
# 26    1                          Da Vinci Code is amazing.
# 27    1                   The Da Vinci Code was awesome...
# 28    1  The Da Vinci Code's backtory on various religi...
# 29    1             Book ( s ): I love The Da Vinci Code..
# ...  ..                                                ...
# 6887  0           Brokeback Mountain is fucking horrible..
# 6888  0  Then snuck into Brokeback Mountain, which is t...
# 6889  0  , she helped me bobbypin my insanely cool hat ...
# 6890  0  My dad's being stupid about brokeback mountain...
# 6891  0  Oh, and Brokeback Mountain is a TERRIBLE movie...
# 6892  0                     Brokeback Mountain was boring.
# 6893  0       So Brokeback Mountain was really depressing.
# 6894  0  As I sit here, watching the MTV Movie Awards, ...
# 6895  0    Ok brokeback mountain is such a horrible movie.
# 6896  0   Oh, and Brokeback Mountain was a terrible movie.
# 6897  0           Brokeback Mountain is fucking horrible..
# 6898  0  Then snuck into Brokeback Mountain, which is t...
# 6899  0  , she helped me bobbypin my insanely cool hat ...
# 6900  0  My dad's being stupid about brokeback mountain...
# 6901  0  Oh, and Brokeback Mountain is a TERRIBLE movie...
# 6902  0                     Brokeback Mountain was boring.
# 6903  0       So Brokeback Mountain was really depressing.
# 6904  0  As I sit here, watching the MTV Movie Awards, ...
# 6905  0    Ok brokeback mountain is such a horrible movie.
# 6906  0   Oh, and Brokeback Mountain was a terrible movie.
# 6907  0           Brokeback Mountain is fucking horrible..
# 6908  0  Then snuck into Brokeback Mountain, which is t...
# 6909  0  , she helped me bobbypin my insanely cool hat ...
# 6910  0  My dad's being stupid about brokeback mountain...
# 6911  0  Oh, and Brokeback Mountain is a TERRIBLE movie...
# 6912  0                     Brokeback Mountain was boring.
# 6913  0       So Brokeback Mountain was really depressing.
# 6914  0  As I sit here, watching the MTV Movie Awards, ...
# 6915  0    Ok brokeback mountain is such a horrible movie.
# 6916  0   Oh, and Brokeback Mountain was a terrible movie.
#
# [6917 rows x 2 columns]

# %%
df.head()
# Out:
#    1            The Da Vinci Code book is just awesome.
# 0  1  this was the first clive cussler i've ever rea...
# 1  1                   i liked the Da Vinci Code a lot.
# 2  1                   i liked the Da Vinci Code a lot.
# 3  1  I liked the Da Vinci Code but it ultimatly did...
# 4  1  that's not even an exaggeration ) and at midni...

# %%
df.isnull().sum()
# Out:
# 1                                          0
# The Da Vinci Code book is just awesome.    0
# dtype: int64

# %%
df.corr()
# Out:
#      1
# 1  1.0

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
plt.figure(figsize=(20, 10))
sns.heatmap(df.corr(), annot=True, cmap='viridis')
sns.set()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6917 entries, 0 to 6916
# Data columns (total 2 columns):
# 1                                          6917 non-null int64
# The Da Vinci Code book is just awesome.    6917 non-null object
# dtypes: int64(1), object(1)
# memory usage: 108.2+ KB

# %%
df.describe()
# Out:
#                  1
# count  6917.000000
# mean      0.569900
# std       0.495126
# min       0.000000
# 25%       0.000000
# 50%       1.000000
# 75%       1.000000
# max       1.000000

# %%
df.shape
# Out:
# (6917, 2)

# %%
df.columns
# Out:
# Index(['1', 'The Da Vinci Code book is just awesome.'], dtype='object')

# %%
df=pd.read_csv('movie_metadata.csv')

# %%
df.columns
# Out:
# Index(['color', 'director_name', 'num_critic_for_reviews', 'duration',
#        'director_facebook_likes', 'actor_3_facebook_likes', 'actor_2_name',
#        'actor_1_facebook_likes', 'gross', 'genres', 'actor_1_name',
#        'movie_title', 'num_voted_users', 'cast_total_facebook_likes',
#        'actor_3_name', 'facenumber_in_poster', 'plot_keywords',
#        'movie_imdb_link', 'num_user_for_reviews', 'language', 'country',
#        'content_rating', 'budget', 'title_year', 'actor_2_facebook_likes',
#        'imdb_score', 'aspect_ratio', 'movie_facebook_likes'],
#       dtype='object')

# %%
df['content_rating']
# Out:
# 0           PG-13
# 1           PG-13
# 2           PG-13
# 3           PG-13
# 4             NaN
# 5           PG-13
# 6           PG-13
# 7              PG
# 8           PG-13
# 9              PG
# 10          PG-13
# 11          PG-13
# 12          PG-13
# 13          PG-13
# 14          PG-13
# 15          PG-13
# 16             PG
# 17          PG-13
# 18          PG-13
# 19          PG-13
# 20          PG-13
# 21          PG-13
# 22          PG-13
# 23          PG-13
# 24          PG-13
# 25          PG-13
# 26          PG-13
# 27          PG-13
# 28          PG-13
# 29          PG-13
#           ...
# 5013          NaN
# 5014            R
# 5015            R
# 5016          NaN
# 5017          NaN
# 5018          NaN
# 5019            R
# 5020          NaN
# 5021            R
# 5022          NaN
# 5023          NaN
# 5024      Unrated
# 5025        NC-17
# 5026            R
# 5027    Not Rated
# 5028          NaN
# 5029          NaN
# 5030          NaN
# 5031          NaN
# 5032          NaN
# 5033        PG-13
# 5034    Not Rated
# 5035            R
# 5036        PG-13
# 5037    Not Rated
# 5038          NaN
# 5039        TV-14
# 5040          NaN
# 5041        PG-13
# 5042           PG
# Name: content_rating, Length: 5043, dtype: object
