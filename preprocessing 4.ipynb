# %%
import pandas as pd
import numpy as np
import requests
import bs4 as bs
import urllib.request
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Extracting features of 2020 movies from Wikipedia

# %%
link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2020"

# %%
source = urllib.request.urlopen(link).read()
soup = bs.BeautifulSoup(source,'lxml')

# %%
tables = soup.find_all('table',class_='wikitable sortable')

# %%
len(tables)
# Out:
# 4

# %%
type(tables[0])
# Out:
# bs4.element.Tag

# %%
df1 = pd.read_html(str(tables[0]))[0]
df2 = pd.read_html(str(tables[1]))[0]
df3 = pd.read_html(str(tables[2]))[0]
df4 = pd.read_html(str(tables[3]).replace("'1\"\'",'"1"'))[0] # avoided "ValueError: invalid literal for int() with base 10: '1"'

# %%
df = df1.append(df2.append(df3.append(df4,ignore_index=True),ignore_index=True),ignore_index=True)

# %%
df.head()
# Out:
#    Opening  Opening.1              Title  \
# 0  JANUARY          3         The Grudge
# 1  JANUARY         10         Underwater
# 2  JANUARY         10        Like a Boss
# 3  JANUARY         10      Three Christs
# 4  JANUARY         10  Inherit the Viper
#
#                                   Production company  \
# 0  Screen Gems / Stage 6 Films / Ghost House Pict...
# 1  20th Century Fox / TSG Entertainment / Chernin...
# 2                                 Paramount Pictures
# 3                                          IFC Films
# 4     Barry Films / Tycor International Film Company
#
#                                        Cast and crew Ref.
# 0  Nicolas Pesce (director/screenplay); Andrea Ri...  [2]
# 1  William Eubank (director); Brian Duffield, Ada...  [3]
# 2  Miguel Arteta (director); Sam Pitman, Adam Col...  [4]
# 3  Jon Avnet (director/screenplay); Eric Nazarian...  NaN
# 4  Anthony Jerjen (director); Andrew Crabtree (sc...  [5]

# %%
df_2020 = df[['Title','Cast and crew']]
pd.set_option('display.max_columns', None)
df_2020.head()
# Out:
#                Title                                      Cast and crew
# 0         The Grudge  Nicolas Pesce (director/screenplay); Andrea Ri...
# 1         Underwater  William Eubank (director); Brian Duffield, Ada...
# 2        Like a Boss  Miguel Arteta (director); Sam Pitman, Adam Col...
# 3      Three Christs  Jon Avnet (director/screenplay); Eric Nazarian...
# 4  Inherit the Viper  Anthony Jerjen (director); Andrew Crabtree (sc...

# %%
from tmdbv3api import TMDb
import json
import requests
tmdb = TMDb()
tmdb.api_key = '58829adce58ecc066162c972cfe72689'

# %%
from tmdbv3api import Movie
tmdb_movie = Movie() 
def get_genre(x):
    genres = []
    result = tmdb_movie.search(x)
    if not result:
      return np.NaN
    else:
      movie_id = result[0].id
      response = requests.get('https://api.themoviedb.org/3/movie/{}?api_key={}'.format(movie_id,tmdb.api_key))
      data_json = response.json()
      if data_json['genres']:
          genre_str = " " 
          for i in range(0,len(data_json['genres'])):
              genres.append(data_json['genres'][i]['name'])
          return genre_str.join(genres)
      else:
          return np.NaN

# %%
df_2020['genres'] = df_2020['Title'].map(lambda x: get_genre(str(x)))
# Out:
# C:\Users\Gaurishankar\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df_2020.head()
# Out:
#                Title                                      Cast and crew  \
# 0         The Grudge  Nicolas Pesce (director/screenplay); Andrea Ri...
# 1         Underwater  William Eubank (director); Brian Duffield, Ada...
# 2        Like a Boss  Miguel Arteta (director); Sam Pitman, Adam Col...
# 3      Three Christs  Jon Avnet (director/screenplay); Eric Nazarian...
# 4  Inherit the Viper  Anthony Jerjen (director); Andrew Crabtree (sc...
#
#                                    genres
# 0                 Horror Mystery Thriller
# 1  Action Horror Science Fiction Thriller
# 2                                  Comedy
# 3                                   Drama
# 4                    Drama Thriller Crime

# %%
def get_director(x):
    if " (director)" in x:
        return x.split(" (director)")[0]
    elif " (directors)" in x:
        return x.split(" (directors)")[0]
    else:
        return x.split(" (director/screenplay)")[0]

# %%
df_2020['director_name'] = df_2020['Cast and crew'].map(lambda x: get_director(str(x)))
# Out:
# C:\Users\Gaurishankar\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df_2020.head()
# Out:
#                Title                                      Cast and crew  \
# 0         The Grudge  Nicolas Pesce (director/screenplay); Andrea Ri...
# 1         Underwater  William Eubank (director); Brian Duffield, Ada...
# 2        Like a Boss  Miguel Arteta (director); Sam Pitman, Adam Col...
# 3      Three Christs  Jon Avnet (director/screenplay); Eric Nazarian...
# 4  Inherit the Viper  Anthony Jerjen (director); Andrew Crabtree (sc...
#
#                                    genres   director_name
# 0                 Horror Mystery Thriller   Nicolas Pesce
# 1  Action Horror Science Fiction Thriller  William Eubank
# 2                                  Comedy   Miguel Arteta
# 3                                   Drama       Jon Avnet
# 4                    Drama Thriller Crime  Anthony Jerjen

# %%
def get_actor1(x):
    return ((x.split("screenplay); ")[-1]).split(", ")[0])

# %%
df_2020['actor_1_name'] = df_2020['Cast and crew'].map(lambda x: get_actor1(str(x)))
# Out:
# C:\Users\Gaurishankar\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df_2020.head()
# Out:
#                Title                                      Cast and crew  \
# 0         The Grudge  Nicolas Pesce (director/screenplay); Andrea Ri...
# 1         Underwater  William Eubank (director); Brian Duffield, Ada...
# 2        Like a Boss  Miguel Arteta (director); Sam Pitman, Adam Col...
# 3      Three Christs  Jon Avnet (director/screenplay); Eric Nazarian...
# 4  Inherit the Viper  Anthony Jerjen (director); Andrew Crabtree (sc...
#
#                                    genres   director_name        actor_1_name
# 0                 Horror Mystery Thriller   Nicolas Pesce  Andrea Riseborough
# 1  Action Horror Science Fiction Thriller  William Eubank     Kristen Stewart
# 2                                  Comedy   Miguel Arteta     Tiffany Haddish
# 3                                   Drama       Jon Avnet        Richard Gere
# 4                    Drama Thriller Crime  Anthony Jerjen       Josh Hartnett

# %%
def get_actor2(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 2:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[1])

# %%
df_2020['actor_2_name'] = df_2020['Cast and crew'].map(lambda x: get_actor2(str(x)))

# %%
df_2020.head()
# Out:
#                Title                                      Cast and crew  \
# 0         The Grudge  Nicolas Pesce (director/screenplay); Andrea Ri...
# 1         Underwater  William Eubank (director); Brian Duffield, Ada...
# 2        Like a Boss  Miguel Arteta (director); Sam Pitman, Adam Col...
# 3      Three Christs  Jon Avnet (director/screenplay); Eric Nazarian...
# 4  Inherit the Viper  Anthony Jerjen (director); Andrew Crabtree (sc...
#
#                                    genres   director_name        actor_1_name  \
# 0                 Horror Mystery Thriller   Nicolas Pesce  Andrea Riseborough
# 1  Action Horror Science Fiction Thriller  William Eubank     Kristen Stewart
# 2                                  Comedy   Miguel Arteta     Tiffany Haddish
# 3                                   Drama       Jon Avnet        Richard Gere
# 4                    Drama Thriller Crime  Anthony Jerjen       Josh Hartnett
#
#         actor_2_name
# 0      Demián Bichir
# 1     Vincent Cassel
# 2         Rose Byrne
# 3     Peter Dinklage
# 4  Margarita Levieva

# %%
def get_actor3(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 3:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[2])

# %%
df_2020['actor_3_name'] = df_2020['Cast and crew'].map(lambda x: get_actor3(str(x)))

# %%
df_2020.head()
# Out:
#                Title                                      Cast and crew  \
# 0         The Grudge  Nicolas Pesce (director/screenplay); Andrea Ri...
# 1         Underwater  William Eubank (director); Brian Duffield, Ada...
# 2        Like a Boss  Miguel Arteta (director); Sam Pitman, Adam Col...
# 3      Three Christs  Jon Avnet (director/screenplay); Eric Nazarian...
# 4  Inherit the Viper  Anthony Jerjen (director); Andrew Crabtree (sc...
#
#                                    genres   director_name        actor_1_name  \
# 0                 Horror Mystery Thriller   Nicolas Pesce  Andrea Riseborough
# 1  Action Horror Science Fiction Thriller  William Eubank     Kristen Stewart
# 2                                  Comedy   Miguel Arteta     Tiffany Haddish
# 3                                   Drama       Jon Avnet        Richard Gere
# 4                    Drama Thriller Crime  Anthony Jerjen       Josh Hartnett
#
#         actor_2_name     actor_3_name
# 0      Demián Bichir         John Cho
# 1     Vincent Cassel  Jessica Henwick
# 2         Rose Byrne      Salma Hayek
# 3     Peter Dinklage   Walton Goggins
# 4  Margarita Levieva   Chandler Riggs

# %%
df_2020 = df_2020.rename(columns={'Title':'movie_title'})

# %%
new_df20 = df_2020.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]

# %%
new_df20.head()
# Out:
#     director_name        actor_1_name       actor_2_name     actor_3_name  \
# 0   Nicolas Pesce  Andrea Riseborough      Demián Bichir         John Cho
# 1  William Eubank     Kristen Stewart     Vincent Cassel  Jessica Henwick
# 2   Miguel Arteta     Tiffany Haddish         Rose Byrne      Salma Hayek
# 3       Jon Avnet        Richard Gere     Peter Dinklage   Walton Goggins
# 4  Anthony Jerjen       Josh Hartnett  Margarita Levieva   Chandler Riggs
#
#                                    genres        movie_title
# 0                 Horror Mystery Thriller         The Grudge
# 1  Action Horror Science Fiction Thriller         Underwater
# 2                                  Comedy        Like a Boss
# 3                                   Drama      Three Christs
# 4                    Drama Thriller Crime  Inherit the Viper

# %%
new_df20['comb'] = new_df20['actor_1_name'] + ' ' + new_df20['actor_2_name'] + ' '+ new_df20['actor_3_name'] + ' '+ new_df20['director_name'] +' ' + new_df20['genres']

# %%
new_df20.comb.head()
# Out:
# 0    Andrea Riseborough Demián Bichir John Cho Nico...
# 1    Kristen Stewart Vincent Cassel Jessica Henwick...
# 2    Tiffany Haddish Rose Byrne Salma Hayek Miguel ...
# 3    Richard Gere Peter Dinklage Walton Goggins Jon...
# 4    Josh Hartnett Margarita Levieva Chandler Riggs...
# Name: comb, dtype: object

# %%
new_df20.head()
# Out:
#     director_name        actor_1_name       actor_2_name     actor_3_name  \
# 0   Nicolas Pesce  Andrea Riseborough      Demián Bichir         John Cho
# 1  William Eubank     Kristen Stewart     Vincent Cassel  Jessica Henwick
# 2   Miguel Arteta     Tiffany Haddish         Rose Byrne      Salma Hayek
# 3       Jon Avnet        Richard Gere     Peter Dinklage   Walton Goggins
# 4  Anthony Jerjen       Josh Hartnett  Margarita Levieva   Chandler Riggs
#
#                                    genres        movie_title  \
# 0                 Horror Mystery Thriller         The Grudge
# 1  Action Horror Science Fiction Thriller         Underwater
# 2                                  Comedy        Like a Boss
# 3                                   Drama      Three Christs
# 4                    Drama Thriller Crime  Inherit the Viper
#
#                                                 comb
# 0  Andrea Riseborough Demián Bichir John Cho Nico...
# 1  Kristen Stewart Vincent Cassel Jessica Henwick...
# 2  Tiffany Haddish Rose Byrne Salma Hayek Miguel ...
# 3  Richard Gere Peter Dinklage Walton Goggins Jon...
# 4  Josh Hartnett Margarita Levieva Chandler Riggs...

# %%
new_df20.isna().sum()
# Out:
# director_name     0
# actor_1_name      0
# actor_2_name      3
# actor_3_name     26
# genres            0
# movie_title       0
# comb             26
# dtype: int64

# %%
new_df20 = new_df20.dropna(how='any')

# %%
new_df20.isna().sum()
# Out:
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# genres           0
# movie_title      0
# comb             0
# dtype: int64

# %%
new_df20['movie_title'] = new_df20['movie_title'].str.lower()

# %%
new_df20.head()
# Out:
#     director_name        actor_1_name       actor_2_name     actor_3_name  \
# 0   Nicolas Pesce  Andrea Riseborough      Demián Bichir         John Cho
# 1  William Eubank     Kristen Stewart     Vincent Cassel  Jessica Henwick
# 2   Miguel Arteta     Tiffany Haddish         Rose Byrne      Salma Hayek
# 3       Jon Avnet        Richard Gere     Peter Dinklage   Walton Goggins
# 4  Anthony Jerjen       Josh Hartnett  Margarita Levieva   Chandler Riggs
#
#                                    genres        movie_title  \
# 0                 Horror Mystery Thriller         the grudge
# 1  Action Horror Science Fiction Thriller         underwater
# 2                                  Comedy        like a boss
# 3                                   Drama      three christs
# 4                    Drama Thriller Crime  inherit the viper
#
#                                                 comb
# 0  Andrea Riseborough Demián Bichir John Cho Nico...
# 1  Kristen Stewart Vincent Cassel Jessica Henwick...
# 2  Tiffany Haddish Rose Byrne Salma Hayek Miguel ...
# 3  Richard Gere Peter Dinklage Walton Goggins Jon...
# 4  Josh Hartnett Margarita Levieva Chandler Riggs...

# %%
old_df = pd.read_csv('../datasets/final_data.csv')

# %%
old_df.head()
# Out:
#        director_name     actor_1_name      actor_2_name          actor_3_name  \
# 0      James Cameron      CCH Pounder  Joel David Moore             Wes Studi
# 1     Gore Verbinski      Johnny Depp     Orlando Bloom        Jack Davenport
# 2         Sam Mendes  Christoph Waltz      Rory Kinnear      Stephanie Sigman
# 3  Christopher Nolan        Tom Hardy    Christian Bale  Joseph Gordon-Levitt
# 4        Doug Walker      Doug Walker        Rob Walker               unknown
#
#                             genres  \
# 0  Action Adventure Fantasy Sci-Fi
# 1         Action Adventure Fantasy
# 2        Action Adventure Thriller
# 3                  Action Thriller
# 4                      Documentary
#
#                                          movie_title  \
# 0                                             avatar
# 1           pirates of the caribbean: at world's end
# 2                                            spectre
# 3                              the dark knight rises
# 4  star wars: episode vii - the force awakens    ...
#
#                                                 comb
# 0  CCH Pounder Joel David Moore Wes Studi James C...
# 1  Johnny Depp Orlando Bloom Jack Davenport Gore ...
# 2  Christoph Waltz Rory Kinnear Stephanie Sigman ...
# 3  Tom Hardy Christian Bale Joseph Gordon-Levitt ...
# 4  Doug Walker Rob Walker unknown Doug Walker Doc...

# %%
final_df = old_df.append(new_df20,ignore_index=True)

# %%
final_df
# Out:
#                 director_name           actor_1_name          actor_2_name  \
# 0               James Cameron            CCH Pounder      Joel David Moore
# 1              Gore Verbinski            Johnny Depp         Orlando Bloom
# 2                  Sam Mendes        Christoph Waltz          Rory Kinnear
# 3           Christopher Nolan              Tom Hardy        Christian Bale
# 4                 Doug Walker            Doug Walker            Rob Walker
# 5              Andrew Stanton           Daryl Sabara       Samantha Morton
# 6                Nathan Greno           Brad Garrett          Donna Murphy
# 7                 Joss Whedon        Chris Hemsworth     Robert Downey Jr.
# 8                 David Yates           Alan Rickman      Daniel Radcliffe
# 9                 Zack Snyder           Henry Cavill          Lauren Cohan
# 10               Bryan Singer           Kevin Spacey         Marlon Brando
# 11               Marc Forster     Giancarlo Giannini       Mathieu Amalric
# 12             Gore Verbinski            Johnny Depp         Orlando Bloom
# 13             Gore Verbinski            Johnny Depp           Ruth Wilson
# 14                Zack Snyder           Henry Cavill    Christopher Meloni
# 15             Andrew Adamson         Peter Dinklage  Pierfrancesco Favino
# 16               Rob Marshall            Johnny Depp           Sam Claflin
# 17           Barry Sonnenfeld             Will Smith     Michael Stuhlbarg
# 18              Peter Jackson           Aidan Turner            Adam Brown
# 19                  Marc Webb             Emma Stone       Andrew Garfield
# 20               Ridley Scott              Mark Addy          William Hurt
# 21              Peter Jackson           Aidan Turner            Adam Brown
# 22                Chris Weitz        Christopher Lee             Eva Green
# 23              James Cameron      Leonardo DiCaprio          Kate Winslet
# 24              Anthony Russo      Robert Downey Jr.    Scarlett Johansson
# 25                 Peter Berg            Liam Neeson   Alexander Skarsgård
# 26            Colin Trevorrow    Bryce Dallas Howard            Judy Greer
# 27                  Sam Raimi           J.K. Simmons          James Franco
# 28                Shane Black      Robert Downey Jr.           Jon Favreau
# 29               Brett Ratner           Hugh Jackman        Kelsey Grammer
# ...                       ...                    ...                   ...
# 6039              Ben Falcone       Melissa McCarthy       Bobby Cannavale
# 6040              Mitja Okorn            Jaden Smith       Cara Delevingne
# 6041              Ashley Avis          Mackenzie Foy          Kate Winslet
# 6042              Ryan Murphy           Meryl Streep          James Corden
# 6043              Marc Meyers          Jessica Rothe        Harry Shum Jr.
# 6044           Sharon Maguire            Isla Fisher          Jillian Bell
# 6045             April Mullen          Aaron Eckhart      Katheryn Winnick
# 6046  Lawrence Michael Levine           Aubrey Plaza    Christopher Abbott
# 6047        Steven Soderbergh           Meryl Streep        Candice Bergen
# 6048           George Clooney         George Clooney        Felicity Jones
# 6049               Adam Mason                 KJ Apa          Sofia Carson
# 6050     John Patrick Shanley            Emily Blunt          Jamie Dornan
# 6051          Reginald Hudlin             Jay Reeves    Thaddeus J. Mixson
# 6052               Tara Miele          Sienna Miller            Diego Luna
# 6053               Julia Hart       Rachel Brosnahan           Arinzé Kene
# 6054             Jamie Babbit         Drew Barrymore         Michael Zegen
# 6055      Adam Egypt Mortimer        Joe Manganiello         Skylan Brooks
# 6056              Ekwa Msangi            Ntare Mwine            Zainab Jah
# 6057      Paul W. S. Anderson         Milla Jovovich              Tony Jaa
# 6058          Ric Roman Waugh          Gerard Butler       Morena Baccarin
# 6059              Deon Taylor           Hilary Swank          Michael Ealy
# 6060           Liam O'Donnell         Lindsey Morgan       Jonathan Howard
# 6061             Shawn Linden             Devon Sawa      Camille Sullivan
# 6062              Eugene Ashe         Tessa Thompson       Nnamdi Asomugha
# 6063            Patty Jenkins              Gal Gadot            Chris Pine
# 6064              Pete Docter             Jamie Foxx              Tina Fey
# 6065         Robert Rodriguez  Priyanka Chopra Jonas          Pedro Pascal
# 6066              Regina King      Kingsley Ben-Adir             Eli Goree
# 6067          Emerald Fennell         Carey Mulligan            Bo Burnham
# 6068         Kornél Mundruczó          Vanessa Kirby          Shia LaBeouf
#
#                 actor_3_name  \
# 0                  Wes Studi
# 1             Jack Davenport
# 2           Stephanie Sigman
# 3       Joseph Gordon-Levitt
# 4                    unknown
# 5               Polly Walker
# 6                M.C. Gainey
# 7         Scarlett Johansson
# 8               Rupert Grint
# 9             Alan D. Purwin
# 10            Frank Langella
# 11              Rory Kinnear
# 12            Jack Davenport
# 13             Tom Wilkinson
# 14              Harry Lennix
# 15            Damián Alcázar
# 16            Stephen Graham
# 17        Nicole Scherzinger
# 18             James Nesbitt
# 19               Chris Zylka
# 20              Scott Grimes
# 21             James Nesbitt
# 22      Kristin Scott Thomas
# 23             Gloria Stuart
# 24               Chris Evans
# 25            Tadanobu Asano
# 26                   Omar Sy
# 27             Kirsten Dunst
# 28               Don Cheadle
# 29            Daniel Cudmore
# ...                      ...
# 6039       Brian Tyree Henry
# 6040        Cuba Gooding Jr.
# 6041          Claire Forlani
# 6042        Jo Ellen Pellman
# 6043              Kyle Allen
# 6044        Santiago Cabrera
# 6045          Heather Graham
# 6046             Sarah Gadon
# 6047              Gemma Chan
# 6048           David Oyelowo
# 6049          Craig Robinson
# 6050                Jon Hamm
# 6051            Corinne Foxx
# 6052              Beth Grant
# 6053  Marsha Stephanie Blake
# 6054             T.J. Miller
# 6055            Zolee Griggs
# 6056            Jayme Lawson
# 6057       Tip "T.I." Harris
# 6058            David Denman
# 6059             Mike Colter
# 6060        Daniel Bernhardt
# 6061              Nick Stahl
# 6062     Ryan Michelle Bathe
# 6063            Kristen Wiig
# 6064           Graham Norton
# 6065           YaYa Gosselin
# 6066             Aldis Hodge
# 6067             Alison Brie
# 6068            Molly Parker
#
#                                                  genres  \
# 0                       Action Adventure Fantasy Sci-Fi
# 1                              Action Adventure Fantasy
# 2                             Action Adventure Thriller
# 3                                       Action Thriller
# 4                                           Documentary
# 5                               Action Adventure Sci-Fi
# 6     Adventure Animation Comedy Family Fantasy Musi...
# 7                               Action Adventure Sci-Fi
# 8                      Adventure Family Fantasy Mystery
# 9                               Action Adventure Sci-Fi
# 10                              Action Adventure Sci-Fi
# 11                                     Action Adventure
# 12                             Action Adventure Fantasy
# 13                             Action Adventure Western
# 14                      Action Adventure Fantasy Sci-Fi
# 15                      Action Adventure Family Fantasy
# 16                             Action Adventure Fantasy
# 17        Action Adventure Comedy Family Fantasy Sci-Fi
# 18                                    Adventure Fantasy
# 19                             Action Adventure Fantasy
# 20                       Action Adventure Drama History
# 21                                    Adventure Fantasy
# 22                             Adventure Family Fantasy
# 23                                        Drama Romance
# 24                              Action Adventure Sci-Fi
# 25                     Action Adventure Sci-Fi Thriller
# 26                     Action Adventure Sci-Fi Thriller
# 27                     Action Adventure Fantasy Romance
# 28                              Action Adventure Sci-Fi
# 29             Action Adventure Fantasy Sci-Fi Thriller
# ...                                                 ...
# 6039                     Comedy Science Fiction Romance
# 6040                                      Drama Romance
# 6041                                              Drama
# 6042                                             Comedy
# 6043                                      Romance Drama
# 6044                              Family Fantasy Comedy
# 6045                             Thriller Crime Mystery
# 6046                              Drama Comedy Thriller
# 6047                                       Comedy Drama
# 6048                              Science Fiction Drama
# 6049                     Thriller Romance Drama Mystery
# 6050                                      Romance Drama
# 6051                               Family Drama History
# 6052                                      Romance Drama
# 6053                                        Drama Crime
# 6054                                             Comedy
# 6055              Action Thriller Crime Science Fiction
# 6056                                      Romance Drama
# 6057                           Fantasy Action Adventure
# 6058                                             Action
# 6059                                           Thriller
# 6060                             Science Fiction Action
# 6061                                    Horror Thriller
# 6062                                      Drama Romance
# 6063                           Fantasy Action Adventure
# 6064        Family Animation Comedy Drama Music Fantasy
# 6065                 Action Fantasy Family Drama Comedy
# 6066                                              Drama
# 6067                               Thriller Crime Drama
# 6068                                              Drama
#
#                                             movie_title  \
# 0                                                avatar
# 1              pirates of the caribbean: at world's end
# 2                                               spectre
# 3                                 the dark knight rises
# 4     star wars: episode vii - the force awakens    ...
# 5                                           john carter
# 6                                               tangled
# 7                               avengers: age of ultron
# 8                harry potter and the half-blood prince
# 9                    batman v superman: dawn of justice
# 10                                     superman returns
# 11                                    quantum of solace
# 12           pirates of the caribbean: dead man's chest
# 13                                      the lone ranger
# 14                                         man of steel
# 15             the chronicles of narnia: prince caspian
# 16          pirates of the caribbean: on stranger tides
# 17                                       men in black 3
# 18            the hobbit: the battle of the five armies
# 19                               the amazing spider-man
# 20                                           robin hood
# 21                  the hobbit: the desolation of smaug
# 22                                   the golden compass
# 23                                              titanic
# 24                           captain america: civil war
# 25                                           battleship
# 26                                       jurassic world
# 27                                         spider-man 2
# 28                                           iron man 3
# 29                                x-men: the last stand
# ...                                                 ...
# 6039                                  superintelligence
# 6040                                     life in a year
# 6041                                       black beauty
# 6042                                           the prom
# 6043                                        all my life
# 6044                                        godmothered
# 6045                                             wander
# 6046                                         black bear
# 6047                                  let them all talk
# 6048                                   the midnight sky
# 6049                                           songbird
# 6050                                wild mountain thyme
# 6051                                             safety
# 6052                                      wander darkly
# 6053                                     i'm your woman
# 6054                                       the stand in
# 6055                                          archenemy
# 6056                                      farewell amor
# 6057                                     monster hunter
# 6058                                          greenland
# 6059                                             fatale
# 6060                                           skylines
# 6061                                      hunter hunter
# 6062                                      sylvie's love
# 6063                                  wonder woman 1984
# 6064                                               soul
# 6065                                   we can be heroes
# 6066                              one night in miami...
# 6067                              promising young woman
# 6068                                  pieces of a woman
#
#                                                    comb
# 0     CCH Pounder Joel David Moore Wes Studi James C...
# 1     Johnny Depp Orlando Bloom Jack Davenport Gore ...
# 2     Christoph Waltz Rory Kinnear Stephanie Sigman ...
# 3     Tom Hardy Christian Bale Joseph Gordon-Levitt ...
# 4     Doug Walker Rob Walker unknown Doug Walker Doc...
# 5     Daryl Sabara Samantha Morton Polly Walker Andr...
# 6     Brad Garrett Donna Murphy M.C. Gainey Nathan G...
# 7     Chris Hemsworth Robert Downey Jr. Scarlett Joh...
# 8     Alan Rickman Daniel Radcliffe Rupert Grint Dav...
# 9     Henry Cavill Lauren Cohan Alan D. Purwin Zack ...
# 10    Kevin Spacey Marlon Brando Frank Langella Brya...
# 11    Giancarlo Giannini Mathieu Amalric Rory Kinnea...
# 12    Johnny Depp Orlando Bloom Jack Davenport Gore ...
# 13    Johnny Depp Ruth Wilson Tom Wilkinson Gore Ver...
# 14    Henry Cavill Christopher Meloni Harry Lennix Z...
# 15    Peter Dinklage Pierfrancesco Favino Damián Alc...
# 16    Johnny Depp Sam Claflin Stephen Graham Rob Mar...
# 17    Will Smith Michael Stuhlbarg Nicole Scherzinge...
# 18    Aidan Turner Adam Brown James Nesbitt Peter Ja...
# 19    Emma Stone Andrew Garfield Chris Zylka Marc We...
# 20    Mark Addy William Hurt Scott Grimes Ridley Sco...
# 21    Aidan Turner Adam Brown James Nesbitt Peter Ja...
# 22    Christopher Lee Eva Green Kristin Scott Thomas...
# 23    Leonardo DiCaprio Kate Winslet Gloria Stuart J...
# 24    Robert Downey Jr. Scarlett Johansson Chris Eva...
# 25    Liam Neeson Alexander Skarsgård Tadanobu Asano...
# 26    Bryce Dallas Howard Judy Greer Omar Sy Colin T...
# 27    J.K. Simmons James Franco Kirsten Dunst Sam Ra...
# 28    Robert Downey Jr. Jon Favreau Don Cheadle Shan...
# 29    Hugh Jackman Kelsey Grammer Daniel Cudmore Bre...
# ...                                                 ...
# 6039  Melissa McCarthy Bobby Cannavale Brian Tyree H...
# 6040  Jaden Smith Cara Delevingne Cuba Gooding Jr. M...
# 6041  Mackenzie Foy Kate Winslet Claire Forlani Ashl...
# 6042  Meryl Streep James Corden Jo Ellen Pellman Rya...
# 6043  Jessica Rothe Harry Shum Jr. Kyle Allen Marc M...
# 6044  Isla Fisher Jillian Bell Santiago Cabrera Shar...
# 6045  Aaron Eckhart Katheryn Winnick Heather Graham ...
# 6046  Aubrey Plaza Christopher Abbott Sarah Gadon La...
# 6047  Meryl Streep Candice Bergen Gemma Chan Steven ...
# 6048  George Clooney Felicity Jones David Oyelowo Ge...
# 6049  KJ Apa Sofia Carson Craig Robinson Adam Mason ...
# 6050  Emily Blunt Jamie Dornan Jon Hamm John Patrick...
# 6051  Jay Reeves Thaddeus J. Mixson Corinne Foxx Reg...
# 6052  Sienna Miller Diego Luna Beth Grant Tara Miele...
# 6053  Rachel Brosnahan Arinzé Kene Marsha Stephanie ...
# 6054  Drew Barrymore Michael Zegen T.J. Miller Jamie...
# 6055  Joe Manganiello Skylan Brooks Zolee Griggs Ada...
# 6056  Ntare Mwine Zainab Jah Jayme Lawson Ekwa Msang...
# 6057  Milla Jovovich Tony Jaa Tip "T.I." Harris Paul...
# 6058  Gerard Butler Morena Baccarin David Denman Ric...
# 6059  Hilary Swank Michael Ealy Mike Colter Deon Tay...
# 6060  Lindsey Morgan Jonathan Howard Daniel Bernhard...
# 6061  Devon Sawa Camille Sullivan Nick Stahl Shawn L...
# 6062  Tessa Thompson Nnamdi Asomugha Ryan Michelle B...
# 6063  Gal Gadot Chris Pine Kristen Wiig Patty Jenkin...
# 6064  Jamie Foxx Tina Fey Graham Norton Pete Docter ...
# 6065  Priyanka Chopra Jonas Pedro Pascal YaYa Gossel...
# 6066  Kingsley Ben-Adir Eli Goree Aldis Hodge Regina...
# 6067  Carey Mulligan Bo Burnham Alison Brie Emerald ...
# 6068  Vanessa Kirby Shia LaBeouf Molly Parker Kornél...
#
# [6069 rows x 7 columns]

# %%
final_df.to_csv('main_data.csv',index=False)

# %%
df=pd.read_csv("C://Users/Gaurishankar/Desktop/Movie-Recommendation-System-with-Sentiment-Analysis-master/main_data.csv")
df.head()
# Out:
#        director_name     actor_1_name      actor_2_name          actor_3_name  \
# 0      James Cameron      CCH Pounder  Joel David Moore             Wes Studi
# 1     Gore Verbinski      Johnny Depp     Orlando Bloom        Jack Davenport
# 2         Sam Mendes  Christoph Waltz      Rory Kinnear      Stephanie Sigman
# 3  Christopher Nolan        Tom Hardy    Christian Bale  Joseph Gordon-Levitt
# 4        Doug Walker      Doug Walker        Rob Walker               unknown
#
#                             genres  \
# 0  Action Adventure Fantasy Sci-Fi
# 1         Action Adventure Fantasy
# 2        Action Adventure Thriller
# 3                  Action Thriller
# 4                      Documentary
#
#                                          movie_title  \
# 0                                             avatar
# 1           pirates of the caribbean: at world's end
# 2                                            spectre
# 3                              the dark knight rises
# 4  star wars: episode vii - the force awakens    ...
#
#                                                 comb
# 0  CCH Pounder Joel David Moore Wes Studi James C...
# 1  Johnny Depp Orlando Bloom Jack Davenport Gore ...
# 2  Christoph Waltz Rory Kinnear Stephanie Sigman ...
# 3  Tom Hardy Christian Bale Joseph Gordon-Levitt ...
# 4  Doug Walker Rob Walker unknown Doug Walker Doc...

# %%
df.tail()
# Out:
#         director_name     actor_1_name     actor_2_name       actor_3_name  \
# 6005  Joseph Kosinski       Tom Cruise     Miles Teller  Jennifer Connelly
# 6006    Joel Crawford     Nicolas Cage       Emma Stone      Ryan Reynolds
# 6007      Liesl Tommy  Jennifer Hudson  Forest Whitaker      Marlon Wayans
# 6008     Ridley Scott       Matt Damon      Adam Driver        Jodie Comer
# 6009  Paul Greengrass        Tom Hanks    Helena Zengel    Neil Sandilands
#
#                           genres        movie_title  \
# 6005                Action Drama  top gun: maverick
# 6006  Animation Adventure Family       the croods 2
# 6007                 Music Drama            respect
# 6008                       Drama      the last duel
# 6009               Drama Western  news of the world
#
#                                                    comb
# 6005  Tom Cruise Miles Teller Jennifer Connelly Jose...
# 6006  Nicolas Cage Emma Stone Ryan Reynolds Joel Cra...
# 6007  Jennifer Hudson Forest Whitaker Marlon Wayans ...
# 6008  Matt Damon Adam Driver Jodie Comer Ridley Scot...
# 6009  Tom Hanks Helena Zengel Neil Sandilands Paul G...

# %%
df.describe()
# Out:
#        director_name    actor_1_name actor_2_name actor_3_name genres  \
# count           6010            6010         6010         6010   6010
# unique          3047            2770         3776         4311   1252
# top          unknown  Robert De Niro      unknown      unknown  Drama
# freq             102              52           23           64    338
#
#               movie_title                                               comb
# count                6010                                               6010
# unique               5978                                               5999
# top     a fantastic woman  Aidan Turner Adam Brown James Nesbitt Peter Ja...
# freq                    2                                                  3

# %%
df.columns
# Out:
# Index(['director_name', 'actor_1_name', 'actor_2_name', 'actor_3_name',
#        'genres', 'movie_title', 'comb'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6010 entries, 0 to 6009
# Data columns (total 7 columns):
# director_name    6010 non-null object
# actor_1_name     6010 non-null object
# actor_2_name     6010 non-null object
# actor_3_name     6010 non-null object
# genres           6010 non-null object
# movie_title      6010 non-null object
# comb             6010 non-null object
# dtypes: object(7)
# memory usage: 328.8+ KB

# %%
sns.catplot(x = 'movie_title', y = 'geners', df = df.sort_values('geners', ascending = False), kind = 'boxen', height = 6, aspect = 3)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-24-1544ec2c03fa> in <module>
# ----> 1 sns.catplot(x = 'movie_title', y = 'geners', df = df.sort_values('geners', ascending = False), kind = 'boxen', height = 6, aspect = 3)
#       2 plt.show()
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position)
#    4717
#    4718             by = by[0]
# -> 4719             k = self._get_label_or_level_values(by, axis=axis)
#    4720
#    4721             if isinstance(ascending, (tuple, list)):
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _get_label_or_level_values(self, key, axis)
#    1704             values = self.axes[axis].get_level_values(key)._values
#    1705         else:
# -> 1706             raise KeyError(key)
#    1707
#    1708         # Check for duplicates
#
# KeyError: 'geners'
